# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Filtrado de Datos
#
# En este laboratorio usaremos el DataFrame creado en la lección anterior resultado de la unión de los conjuntos de datos compartidos contigo.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.

# %%
import pandas as pd
import numpy as np

# %%
# Carga el dataset de trabajo
netflix_filtrado = pd.read_csv('datos/laboratorio-modulo2-leccion02-eda-unionfinal.csv', index_col=0)
netflix_filtrado.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language',
#        'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### Ejercicio 1: ¿Cuáles son todos los títulos lanzados en 2021 que son del tipo 'Movie'?

# %%
condicion_movie = netflix_filtrado['type'] == 'Movie'
condicion_año = netflix_filtrado['release_year'] == 2021
ejercicio1 = netflix_filtrado[condicion_año & condicion_movie]

ejercicio1.head(5)
# Out:
#                         Title             Genre           Premiere  Runtime  \
# 9          Sardar Ka Grandson            Comedy       May 18, 2021      139
# 17  What Happened to Mr. Cha?            Comedy    January 1, 2021      102
# 21      The Girl on the Train          Thriller  February 26, 2021      120
# 22              Thunder Force  Superhero-Comedy      April 9, 2021      105
# 24               Just Say Yes   Romantic comedy      April 2, 2021       97
#
#     IMDB Score Language   type                      title  \
# 9          4.1    Hindi  Movie         Sardar Ka Grandson
# 17         4.3   Korean  Movie  What Happened to Mr. Cha?
# 21         4.4    Hindi  Movie      The Girl on the Train
# 22         4.4  English  Movie              Thunder Force
# 24         4.5    Dutch  Movie               Just Say Yes
#
#                              director  \
# 9                       Kaashvie Nair
# 17                       Kim Dong-kyu
# ...

# %%
netflix_filtrado[(netflix_filtrado['type'] == 'Movie') & (netflix_filtrado['release_year'] == 2021)].head(5)
# Out:
#                         Title             Genre           Premiere  Runtime  \
# 9          Sardar Ka Grandson            Comedy       May 18, 2021      139
# 17  What Happened to Mr. Cha?            Comedy    January 1, 2021      102
# 21      The Girl on the Train          Thriller  February 26, 2021      120
# 22              Thunder Force  Superhero-Comedy      April 9, 2021      105
# 24               Just Say Yes   Romantic comedy      April 2, 2021       97
#
#     IMDB Score Language   type                      title  \
# 9          4.1    Hindi  Movie         Sardar Ka Grandson
# 17         4.3   Korean  Movie  What Happened to Mr. Cha?
# 21         4.4    Hindi  Movie      The Girl on the Train
# 22         4.4  English  Movie              Thunder Force
# 24         4.5    Dutch  Movie               Just Say Yes
#
#                              director  \
# 9                       Kaashvie Nair
# 17                       Kim Dong-kyu
# ...

# %% [markdown]
# #### Ejercicio 2: ¿Qué títulos tienen una duración de 90 minutos? Muestra solo las columnas de título y de duración.

# %%
condicion_duracion = netflix_filtrado['Runtime'] == 90
netflix_filtrado.loc[condicion_duracion,['Title','Runtime']]
# Out:
#                       Title  Runtime
# 4               Kaali Khuhi       90
# 13                    Mercy       90
# 61   The Larva Island Movie       90
# 123     One-Way to Tomorrow       90
# 149         The Wrong Missy       90
# 155            American Son       90
# 195                 Juanita       90
# 223          The Perfection       90
# 231        High Flying Bird       90
# 252             June & Kopi       90
# 288         The Willoughbys       90
# 342            Giving Voice       90
# 462         Team Foxcatcher       90
# 479    Dick Johnson Is Dead       90

# %% [markdown]
# #### Ejercicio 3: ¿Cuáles son todos los títulos del país 'India' lanzados después de 2018?

# %%
netflix_filtrado[(netflix_filtrado['country'] == 'India') & (netflix_filtrado['release_year'] > 2018)].head(5)
# Out:
#                     Title             Genre           Premiere  Runtime  \
# 4             Kaali Khuhi           Mystery   October 30, 2020       90
# 5                   Drive            Action   November 1, 2019      147
# 9      Sardar Ka Grandson            Comedy       May 18, 2021      139
# 15          Ghost Stories  Horror anthology    January 1, 2020      144
# 21  The Girl on the Train          Thriller  February 26, 2021      120
#
#     IMDB Score Language   type                  title  \
# 4          3.4    Hindi  Movie            Kaali Khuhi
# 5          3.5    Hindi  Movie                  Drive
# 9          4.1    Hindi  Movie     Sardar Ka Grandson
# 15         4.3    Hindi  Movie          Ghost Stories
# 21         4.4    Hindi  Movie  The Girl on the Train
#
#                                              director  \
# 4                                     Terrie Samundra
# 5                                    Tarun Mansukhani
# ...

# %% [markdown]
# #### Ejercicio 4: ¿Qué títulos tienen clasificación 'TV-14' o 'R'?

# %%
netflix_filtrado[(netflix_filtrado['rating'] == 'TV-14') | (netflix_filtrado['rating'] == 'R')].head(5)
# Out:
#                        Title               Genre            Premiere  Runtime  \
# 4                Kaali Khuhi             Mystery    October 30, 2020       90
# 5                      Drive              Action    November 1, 2019      147
# 9         Sardar Ka Grandson              Comedy        May 18, 2021      139
# 11                   Whipped     Romantic comedy  September 18, 2020       97
# 16  The Last Thing He Wanted  Political thriller   February 21, 2020      115
#
#     IMDB Score    Language   type                     title          director  \
# 4          3.4       Hindi  Movie               Kaali Khuhi   Terrie Samundra
# 5          3.5       Hindi  Movie                     Drive  Tarun Mansukhani
# 9          4.1       Hindi  Movie        Sardar Ka Grandson     Kaashvie Nair
# 11         4.1  Indonesian  Movie                   Whipped      Chandra Liow
# 16         4.3     English  Movie  The Last Thing He Wanted          Dee Rees
#
# ...

# %% [markdown]
# #### Ejercicio 5: ¿Cuáles son los títulos dirigidos por 'Christopher Nolan' o 'Martin Scorsese'? ¿Cuántos a dirigido cada uno de los directores?

# %%
netflix_filtrado[(netflix_filtrado['director'] == 'Christopher Nolan') | (netflix_filtrado['director'] == 'Martin Scorsese')]
# Out:
#             Title        Genre           Premiere  Runtime  IMDB Score  \
# 496  The Irishman  Crime drama  November 27, 2019      209         7.8
#
#     Language   type         title         director  \
# 496  English  Movie  The Irishman  Martin Scorsese
#
#                                                   cast        country  \
# 496  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...  United States
#
#             date_added  release_year rating duration listed_in  \
# 496  November 27, 2019          2019      R  209 min    Dramas
#
#                                            description
# 496  Hit man Frank Sheeran looks back at the secret...

# %% [markdown]
# Solo hay una película de Martin Scorsese

# %% [markdown]
# #### Ejercicio 6: ¿Qué títulos pertenecen a los países 'United States', 'United Kingdom' o 'Canada'? Dentro de estos países, ¿cuántas películas tienen más de un lenguaje?

# %%
paises = ['United States', 'United Kingdom', 'Canada']
paises_merged = netflix_filtrado[netflix_filtrado['country'].isin(paises)]
paises_merged['country'].value_counts()
# Out:
# country
# United States     274
# United Kingdom     13
# Canada              4
# Name: count, dtype: int64

# %%
paises_merged.shape
# Out:
# (291, 17)

# %%
atron_regex = '/'
filtro = netflix_filtrado['Language'].str.contains(atron_regex)
x = paises_merged[filtro]
x.groupby('country')['Title'].count()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17212\3487461305.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x = paises_merged[filtro]
# country
# United States    10
# Name: Title, dtype: int64

# %% [markdown]
# #### Ejercicio 7: ¿Qué títulos fueron lanzados entre 2015 y 2020, inclusive?

# %%
netflix_filtrado.dtypes
# Out:
# Title            object
# Genre            object
# Premiere         object
# Runtime           int64
# IMDB Score      float64
# Language         object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %%
filtro_between = netflix_filtrado['release_year'].between(2015, 2020, inclusive='both')
netflix_filtrado[filtro_between]
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 508                       Cuba and the Cameraman            Documentary
# 509                       Dancing with the Birds            Documentary
# 510  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 511                      Springsteen on Broadway           One-man show
# 512     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language   type  \
# ...

# %% [markdown]
# #### Ejercicio 8: ¿Cuáles son los títulos cuya puntuación en IMDb está entre 6.5 y 8.0 y que no sepamos cual es su duración?

# %%
filtro_imdb = netflix_filtrado['IMDB Score'].between(6.5, 8.0, inclusive='both')
netflix_filtrado[filtro_imdb]
# Out:
#                                          Title                  Genre  \
# 294                             A 3 Minute Hug            Documentary
# 295                           All Together Now                  Drama
# 296                  Altered Carbon: Resleeved  Anime/Science fiction
# 297  Antoine Griezmann: The Making of a Legend            Documentary
# 298                                     Canvas      Animation / Short
# ..                                         ...                    ...
# 497                 The Trial of the Chicago 7                  Drama
# 498                              A Secret Love            Documentary
# 499                                     Icarus            Documentary
# 500                             Marriage Story                  Drama
# 501                             The Ivory Game            Documentary
#
#               Premiere  Runtime  IMDB Score         Language   type  \
# ...

# %% [markdown]
# #### Ejercicio 9: ¿Cuáles son las películas cuya duración de 90 o 150 minutos?

# %%
netflix_filtrado[(netflix_filtrado['Runtime'] == 90) | (netflix_filtrado['Runtime'] == 150)]
# Out:
#                       Title                       Genre           Premiere  \
# 4               Kaali Khuhi                     Mystery   October 30, 2020
# 13                    Mercy                    Thriller  November 22, 2016
# 61   The Larva Island Movie                   Animation      July 23, 2020
# 123     One-Way to Tomorrow                     Romance      June 19, 2020
# 149         The Wrong Missy                      Comedy       May 13, 2020
# 155            American Son                       Drama   November 1, 2019
# 195                 Juanita                       Drama      March 8, 2019
# 223          The Perfection             Horror-thriller       May 24, 2019
# 231        High Flying Bird                Sports-drama   February 8, 2019
# 252             June & Kopi                       Drama   January 28, 2021
# 288         The Willoughbys  Animation/Comedy/Adventure     April 22, 2020
# ...

# %% [markdown]
# #### Ejercicio 10: ¿Cuáles son los títulos que contienen la palabra 'Love' en su título y que sean de tipo TV Show?

# %%
patron_regex = 'love'
filtro_regex = netflix_filtrado['Title'].str.contains(patron_regex, case = False, na= False) ### decide si es sensible o no a las mayúsculas
netflix_filtrado = netflix_filtrado[filtro_regex]
netflix_filtrado
# Out:
#                                       Title              Genre  \
# 53               Love Like the Falling Rain              Drama
# 55                             Squared Love    Romantic comedy
# 106                     Love Wedding Repeat    Romantic comedy
# 111                 The Cloverfield Paradox    Science fiction
# 120                        Falling Inn Love    Romantic comedy
# 122                        Love, Guaranteed    Romantic comedy
# 167                            Rich in Love    Romantic comedy
# 202  To All the Boys: P.S. I Still Love You    Romantic comedy
# 221                           The Lovebirds    Romantic comedy
# 244                        Alex Strangelove    Romantic comedy
# 262                      The Forest of Love              Drama
# 360                 A Love Song for Latasha        Documentary
# 495          If Anything Happens I Love You  Animation / Short
# 498                           A Secret Love        Documentary
#
# ...

# %% [markdown]
# #### Ejercicio 11: ¿Cuáles son los títulos en los que el director tiene el apellido 'Johnson'?

# %%
patron_director = 'Johnson'
filtro_director1 = netflix_filtrado['director'].str.contains(patron_director, case = False, na= False) ### decide si es sensible o no a las mayúsculas
netflix_filtrado[filtro_director1]
# Out:
#                     Title            Genre           Premiere  Runtime  \
# 122      Love, Guaranteed  Romantic comedy  September 3, 2020       91
# 195               Juanita            Drama      March 8, 2019       90
# 244      Alex Strangelove  Romantic comedy       June 8, 2018       99
# 479  Dick Johnson Is Dead      Documentary    October 2, 2020       90
#
#      IMDB Score Language   type                 title             director  \
# 122         5.6  English  Movie      Love, Guaranteed  Mark Steven Johnson
# 195         6.0  English  Movie               Juanita        Clark Johnson
# 244         6.3  English  Movie      Alex Strangelove        Craig Johnson
# 479         7.5  English  Movie  Dick Johnson Is Dead      Kirsten Johnson
#
#                                                   cast        country  \
# 122  Rachael Leigh Cook, Damon Wayans Jr., Heather ...  United States
# 195  Alfre Woodard, Adam Beach, LaTanya Richardson ...  United States
# ...

# %% [markdown]
# #### Ejercicio 12: ¿Tenemos algún documental ('Documentaries') de Mike Tyson?

# %%
filtro_docs = netflix_filtrado['listed_in'].str.contains('Documentaries',case=False,na=False)
netflix_filtrado[filtro_docs]
# Out:
#                                                 Title                  Genre  \
# 0                                     Enter the Anime            Documentary
# 14                                     After the Raid            Documentary
# 28                                        After Maria            Documentary
# 33                                         We Are One            Documentary
# 62   American Factory: A Conversation with the Obamas  Aftershow / Interview
# ..                                                ...                    ...
# 507             The Three Deaths of Marisela Escobedo            Documentary
# 508                            Cuba and the Cameraman            Documentary
# 509                            Dancing with the Birds            Documentary
# 510       Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 512          David Attenborough: A Life on Our Planet            Documentary
#
# ...

# %%
filtro_mike = netflix_filtrado['cast'].str.contains('Mike Tyson',case=False,na=False)
netflix_filtrado[filtro_mike]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
x = netflix_filtrado[filtro_mike & filtro_docs]
x
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Ejercicio 13: Selecciona solo las columnas 'title', 'country' y 'release_year' del dataset.

# %%
netflix_filtrado.loc[:,['title', 'country', 'release_year']]
# Out:
#                                            title  \
# 0                                Enter the Anime
# 1                                    Dark Forces
# 2                                        The App
# 3                                 The Open House
# 4                                    Kaali Khuhi
# ..                                           ...
# 508                       Cuba and the Cameraman
# 509                       Dancing with the Birds
# 510  Winter on Fire: Ukraine's Fight for Freedom
# 511                      Springsteen on Broadway
# 512     David Attenborough: A Life on Our Planet
#
#                                     country  release_year
# 0                      United States, Japan          2019
# 1                                    Mexico          2020
# 2                                     Italy          2019
# 3                     Canada, United States          2018
# 4                                     India          2020
# ...

# %% [markdown]
# #### Ejercicio 14: Filtra las columnas que contienen la palabra 'date'.

# %%
netflix_filtrado.filter(regex= 'date', axis=1)
# Out:
#             date_added
# 0       August 5, 2019
# 1      August 21, 2020
# 2    December 26, 2019
# 3     January 19, 2018
# 4     October 30, 2020
# ..                 ...
# 508  November 24, 2017
# 509   October 23, 2019
# 510    October 9, 2015
# 511  December 16, 2018
# 512    October 4, 2020
#
# [513 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 15: Usando `query()`, filtra todos los títulos del país 'France' con una duración de 80 minutos.

# %%
france = netflix_filtrado.query('country == "France" and Runtime == 80')
france
# Out:
#          Title   Genre       Premiere  Runtime  IMDB Score Language   type  \
# 36  Sentinelle  Action  March 5, 2021       80         4.7   French  Movie
#
#          title         director  \
# 36  Sentinelle  Julien Leclercq
#
#                                                  cast country     date_added  \
# 36  Olga Kurylenko, Marilyn Lima, Michel Nabokoff,...  France  March 5, 2021
#
#     release_year rating duration  \
# 36          2021  TV-MA   81 min
#
#                                            listed_in  \
# 36  Action & Adventure, Dramas, International Movies
#
#                                           description
# 36  Transferred home after a traumatizing combat m...

# %% [markdown]
# #### Ejercicio 16: Filtra los títulos que son películas ('Movie') y fueron lanzados antes de 2010.

# %%
netflix_filtrado.dtypes
# Out:
# Title            object
# Genre            object
# Premiere         object
# Runtime           int64
# IMDB Score      float64
# Language         object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %%
movie = netflix_filtrado.query('type == "Movie" and release_year < 2010')
movie
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# No me da resultados porque mis datos van a partir del 2014

# %% [markdown]
# #### Ejercicio 17: Encuentra los 10 títulos con las puntuaciones más altas en IMDb.

# %%
netflix_top5 = netflix_filtrado.nlargest(10, 'IMDB Score').filter(['IMDB Score', 'Title'])
netflix_top5
# Out:
#      IMDB Score                                        Title
# 512         9.0     David Attenborough: A Life on Our Planet
# 511         8.5                      Springsteen on Broadway
# 510         8.4  Winter on Fire: Ukraine's Fight for Freedom
# 508         8.3                       Cuba and the Cameraman
# 509         8.3                       Dancing with the Birds
# 505         8.2                                        Klaus
# 506         8.2                                   Seaspiracy
# 507         8.2        The Three Deaths of Marisela Escobedo
# 502         8.1                                Chasing Coral
# 503         8.1                           My Octopus Teacher

# %% [markdown]
# #### Ejercicio 18: Encuentra los 5 títulos con las puntuaciones más bajas en IMDb.

# %%
netflix_minus5 = netflix_filtrado.nsmallest(5, 'IMDB Score').filter(['IMDB Score', 'Title'])
netflix_minus5
# Out:
#    IMDB Score            Title
# 0         2.5  Enter the Anime
# 1         2.6      Dark Forces
# 2         2.6          The App
# 3         3.2   The Open House
# 4         3.4      Kaali Khuhi

# %% [markdown]
# #### Ejercicio 19: Filtra todos los títulos que no tienen un director asignado (valores nulos en la columna 'director').

# %%
netflix_filtrado['title'][netflix_filtrado["director"].isnull()]
# Out:
# 6                                      Leyla Everlasting
# 62      American Factory: A Conversation with the Obamas
# 64                                    Father of the Year
# 188                         The Minimalists: Less Is Now
# 201                                  The Princess Switch
# 214                                            Otherhood
# 218                                          Stuck Apart
# 256                                                Polar
# 276                    John Was Trying to Contact Aliens
# 278             Murder to Mercy: The Cyntoia Brown Story
# 297            Antoine Griezmann: The Making of a Legend
# 301                    Dolly Parton: A MusiCares Tribute
# 317                                             Bad Trip
# 372             The Boys in the Band: Something Personal
# 398    Ma Rainey's Black Bottom: A Legacy Brought to ...
# 413                              Derren Brown: Sacrifice
# ...

# %% [markdown]
# #### Ejercicio 20: Filtra todos los títulos que tienen información completa en las columnas 'title', 'country' y 'IMDB Score'.

# %%
filtro_null1 = netflix_filtrado['title'].notnull()
filtro_null2 = netflix_filtrado['country'].notnull()
filtro_null3 = netflix_filtrado['IMDB Score'].notnull()

not_nulos = netflix_filtrado['title'][filtro_null1 & filtro_null2 & filtro_null3]
# Out:
# 0                                  Enter the Anime
# 1                                      Dark Forces
# 2                                          The App
# 3                                   The Open House
# 4                                      Kaali Khuhi
#                           ...
# 508                         Cuba and the Cameraman
# 509                         Dancing with the Birds
# 510    Winter on Fire: Ukraine's Fight for Freedom
# 511                        Springsteen on Broadway
# 512       David Attenborough: A Life on Our Planet
# Name: title, Length: 499, dtype: object

# %% [markdown]
# #### Ejercicio 21: Identifica si hay títulos duplicados en la columna 'title'.

# %%
titles_duplicados = netflix_filtrado[netflix_filtrado.duplicated()]
titles_duplicados
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []
